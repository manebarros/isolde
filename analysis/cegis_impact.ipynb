# %%
import pandas as pd
import preprocessing as pre
import domain as dom

problems = [
    dom.Problem.from_str("Ser_ax_b\tSer_ax_c"),
    dom.Problem.from_str("RA_ax_b\tRA_tap_b"),
    dom.Problem.from_str("SI_ax_b UpdateSer__b\tSer_ax_b"),
    dom.Problem.from_str("SI_ax_b UpdateSer__b\tSer_ax_c"),
]

df = pre.preprocess(pd.read_csv('/home/mane/code/minsolde/isolde-experiments/data/ebd6d29ca72afa.csv'), txn_num=(3,5), problems=problems, implementations = ["all", "no_learning"])
df
# Out:
#    implementation   solver          problem  num_txn  num_keys  num_values  \
# 0             all  glucose     RA_b|TapRA_b        3         5           5
# 1             all  glucose     RA_b|TapRA_b        4         5           5
# 2             all  glucose     RA_b|TapRA_b        5         5           5
# 3             all  glucose  SI_b US_b|Ser_b        3         5           5
# 4             all  glucose  SI_b US_b|Ser_b        4         5           5
# 5             all  glucose  SI_b US_b|Ser_b        5         5           5
# 6             all  glucose  SI_b US_b|Ser_c        3         5           5
# 7             all  glucose  SI_b US_b|Ser_c        4         5           5
# 8             all  glucose  SI_b US_b|Ser_c        5         5           5
# 9             all  glucose      Ser_b|Ser_c        3         5           5
# 10            all  glucose      Ser_b|Ser_c        4         5           5
# 11            all  glucose      Ser_b|Ser_c        5         5           5
# 12    no_learning  glucose     RA_b|TapRA_b        3         5           5
# 13    no_learning  glucose  SI_b US_b|Ser_b        3         5           5
# 14    no_learning  glucose  SI_b US_b|Ser_c        3         5           5
# 15    no_learning  glucose      Ser_b|Ser_c        3         5           5
#
#     num_sessions  candidates  initial_clauses  final_clauses  avg_time_ms  \
# 0              3           0            12470          12470           11
# 1              3           0            22776          22776           31
# 2              3           0            41150          41150          110
# 3              3           2            10613          10705           18
# 4              3           7            16631          17402           38
# 5              3           7            28292          29663           54
# 6              3           5            16626          18596           22
# 7              3           3            41449          43273           32
# 8              3          13            95234         106112          102
# 9              3           6             7365          10147           30
# 10             3          23             9826          22905          557
# 11             3         103            15251          79713         9788
# 12             3          -1               -1             -1       300000
# 13             3          -1               -1             -1       300000
# 14             3          -1               -1             -1       300000
# 15             3          -1               -1             -1       300000
#
#     min_time_ms  max_time_ms  outcome expected
# 0            10           11    UNSAT    UNSAT
# 1            30           32    UNSAT    UNSAT
# 2           109          112    UNSAT    UNSAT
# 3            13           28      SAT      SAT
# 4            36           40      SAT      SAT
# 5            54           55      SAT      SAT
# 6            21           22      SAT      SAT
# 7            31           32      SAT      SAT
# 8           101          103      SAT      SAT
# 9            29           30    UNSAT    UNSAT
# 10          557          558    UNSAT    UNSAT
# 11         9498        10263    UNSAT    UNSAT
# 12       300000       300000  TIMEOUT    UNSAT
# 13       300000       300000  TIMEOUT      SAT
# 14       300000       300000  TIMEOUT      SAT
# 15       300000       300000  TIMEOUT    UNSAT
